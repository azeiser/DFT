# %% [markdown]
# # Diskrete Fourier Transformation

# %% [markdown]
# Import von Bibliotheken

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Beispielfunktion
# Gegeben sei die 2-periodische Funktion $$f(t) = t\cdot (2-t), \quad 0\le t \le 2.$$

# %%
def f(t):
    t_mod = np.mod(t,2)
    return t_mod * (2-t_mod)

# %% [markdown]
# Diese Funktion wollen wir graphisch darstellen. Dazu erzeugen wir uns einen Vektor mit 1001 Werten zwischen -3 und 5.

# %%
tfull = np.linspace(-3,5,1001)

# %% [markdown]
# An diesen Stellen werten wir die Funktion aus und speichern die Werte in einem Vektor.

# %%
yfull = f(tfull)

# %% [markdown]
# Jetzt können wir den Graph plotten.

# %%
plt.figure()
plt.plot(tfull,yfull)
plt.show()

# %% [markdown]
# ## Sampling
# Jetzt wollen wir die Funktion im Intervall $[0,2]$ abtasten. Dazu teilen wir das Intervall in 8 gleich große Teilstücke und nehmen die 9 Endpunkte:

# %%
t = np.linspace(0,2,9) # 9 Punkte zwischen 0 und 2
print(t)
# Out:
# [0.   0.25 0.5  0.75 1.   1.25 1.5  1.75 2.  ]

# %% [markdown]
# Wir bestimmen die Funktionswerte an diesen Punkten

# %%
y = f(t)
print(y)
# Out:
# [0.     0.4375 0.75   0.9375 1.     0.9375 0.75   0.4375 0.    ]

# %% [markdown]
# Diese Punkte können wir zusammen mit der ursrpünglichen Funktion darstellen:

# %%
plt.figure()
plt.plot(tfull,yfull, label="Funktion")
plt.scatter(t,y, c="red", label="Abtastung")
plt.xlim((-1,3))
plt.legend()
plt.show()

# %% [markdown]
# Wir sehen, dass der neunte Datenpunkt wegen der Periodizität gleich dem ersten ist. Daher reicht es nur die ersten 8 Werten zu nehmen. Wir definieren daher

# %%
dt = 2.0/8.0
t = np.arange(0,8) * dt # Vektor [0, 1, 2, ..., 7] mit dt multipliziert
print(t)
# Out:
# [0.   0.25 0.5  0.75 1.   1.25 1.5  1.75]

# %% [markdown]
# und werten die Funktion an diesen Punkten aus:

# %%
y = f(t)
print(y)
# Out:
# [0.     0.4375 0.75   0.9375 1.     0.9375 0.75   0.4375]

# %% [markdown]
# Graphisch auf einer Periode dargestellt:

# %%
plt.figure()
plt.plot(tfull,yfull, label="Funktion")
plt.scatter(t,y, c="red", label="Abtastung")
plt.xlim((0,2))
plt.legend()
plt.show()

# %% [markdown]
# Insgesamt genügt es nach dem Sampling, den Vektor y zu kennen, d.h. den Wert der Funktion an 8 Punkten.

# %% [markdown]
# ## Diskrete harmonische Schwingungen

# %% [markdown]
# Tipp für harmonische Funktionen:

# %%
y = np.sin(2*np.pi/2 * t)
plt.figure()
plt.scatter(t,y)
plt.xlim((0,2))
plt.show()

# %% [markdown]
# Tipp für Skalarprodukt

# %%
print( np.dot(y,y))
# Out:
# 4.0
